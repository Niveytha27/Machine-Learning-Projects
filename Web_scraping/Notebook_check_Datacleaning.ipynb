# %%
import pandas as pd
import numpy as np
import re

# %%
data=pd.read_csv('Notebookcheck_last_3_months_data.csv')
data.head(2)
# Out:
#                                         Product_name  \
# 0     Lenovo Yoga 6 13 82ND0009US (Yoga 6 13 Series)
# 1  Asus ZenBook Flip 13 UX363EA-HP069T (ZenBook F...
#
#                                            Processor  \
# 0  AMD Ryzen 5 5500U 6 x 2.1 - 4 GHz, 21 W PL2 / ...
# 1  Intel Core i7-1165G7 4 x 2.8 - 4.7 GHz, 51 W P...
#
#                                     Graphics adapter  \
# 0  AMD Radeon RX Vega 7 - 512 MB, Memory: 1333 MH...
# 1  Intel Iris Xe Graphics G7 96EUs, Memory: 1300 ...
#
#                                               Memory  \
# 0  8192 MB  , 1600 MHz, 22-22-22-52, Dual-Channel...
# 1                  16384 MB  , LPDDR4-4266, soldered
#
#                                              Display  \
# 0  13.30 inch 16:9, 1920 x 1080 pixel 166 PPI, 10...
# 1  13.30 inch 16:9, 1920 x 1080 pixel 166 PPI, mu...
#
#                                              Storage  \
# 0                WDC PC SN530 SDBPMPZ-265G, 256 GB
# 1  WDC PC SN730 SDBPNTY-1T00, 1024 GB  , 950 GB free
#
#                                                 Size  \
# 0  height x width x depth (in mm): 18.2 x 308 x 2...
# 1  height x width x depth (in mm): 13 x 305 x 211...
#
#                        Battery  \
# 0        60 Wh Lithium-Polymer
# 1  67 Wh, 4220 mAh Lithium-Ion
#
#                                               Camera  \
# 0               Webcam: 720pPrimary Camera: 0.9 MPix
# 1  Webcam: HDPrimary Camera: 0.9 MPixSecondary Ca...
#
#                                               Weight      Price  \
# 0  1.331 kg ( = 46.95 oz / 2.93 pounds), Power Su...    800 USD
# 1  1.188 kg ( = 41.91 oz / 2.62 pounds), Power Su...  1,799 EUR
#
#                                             URL_link
# 0  https://www.notebookcheck.net/Lenovo-Yoga-6-13...
# 1  https://www.notebookcheck.net/Asus-ZenBook-Fli...

# %%
# Functions for cleaning each column data
def clean_processor(text):
    proc_details = text.split(',')
    if len(proc_details) >= 3:
        processor = proc_details[0]
        pl2 = re.search(r'([0-9]+)\sW',proc_details[1]).group(1)
        pl1 = re.search(r'([0-9]+)\sW',proc_details[2]).group(1)
    else:
        processor = proc_details[0]
        pl2 = 'NA'
        pl1 = 'NA'       
        
    return [processor,pl2,pl1]

def clean_memory(text):
    mem_details = text.split(',')
    memory = re.search(r'([0-9]+)\sMB',mem_details[0]).group(1)
    memory = int(memory)//1000
    return memory

def clean_display(text):
    disp_details = text.split(',')
    display,asp_ratio = re.search(r'([0-9\.]+)\sinch\s([0-9:]+)',disp_details[0]).groups()
    return [display,asp_ratio]   

def clean_storage(text):
    storage_details = text.split(',')
    storage = re.search(r'([0-9]+)\sGB',storage_details[1]).group(1)
    return storage

def clean_size(text):
    size_details = text.split(':')
    height,width,depth = re.search(r'\=\s([0-9.]+)\sx\s([0-9.]+)\sx\s([0-9.]+)\sin',size_details[1]).groups()
    return height,width,depth

def clean_battery(text):
    battery = re.search(r'([0-9.]+)\sWh',text).group(1)
    return battery 

def clean_camera(text):
    if type(text) != str:
        return 'NA'
    
    cam = re.search(r'([0-9.]+)\sMP',text)
    if cam:
        return cam.group(1) 
    else:
        return 'NA'

def clean_weight(text):
    weight = re.search(r'([0-9.]+)\skg',text)
    if weight:
        return weight.group(1)
    else:
        weight = re.search(r'([0-9]+)\sg',text)
        return int(weight.group(1))/1000
    
def clean_price(text):
    if type(text) != str:
        return 'NA'
    
    price,currency = text.split(' ')
    if not price.isnumeric():
        price = re.sub(r'[,.]','',price)
        
    if currency.lower() == 'usd':
        conv_price = 75 * int(price)
    elif currency.lower().startswith('eur'):
        conv_price = 87 * int(price)
        
    return conv_price

# %%
# clean_processor
data[['Processor','PL2(in W)','PL1(in W)']] = data.Processor.apply(lambda x: pd.Series(clean_processor(x)))

# Brand_name 
data['Brand_name']=data.Product_name.apply(lambda x: pd.Series(str(x).split(' ')))[0]

# clean_memory 
data['Memory(in GB)']= data.Memory.apply(lambda x: pd.Series(clean_memory(x)))

# clean_display
data[['Display(in inches)','Aspect_ratio']] = data['Display'].apply(lambda x: pd.Series(clean_display(x)))

# Graphics adapter
data['Graphics adapter']=data['Graphics adapter'].apply(lambda x: pd.Series(str(x).split(',')))[0]

# clean_storage
data['Storage(in GB)']= data['Storage'].apply(lambda x: pd.Series(clean_storage(x)))

# clean_size
data[['Height(in inches)','Width(in inches)','Depth(in inches)']] = data['Size'].apply(lambda x: pd.Series(clean_size(x)))

# clean_battery
data['Battery(in Wh)']= data['Battery'].apply(lambda x: pd.Series(clean_battery(x)))

# clean_camera
data['Camera(in MP)']= data['Camera'].apply(lambda x: pd.Series(clean_camera(x)))

# clean_weight
data['Weight(in kg)']= data['Weight'].apply(lambda x: pd.Series(clean_weight(x)))

# clean_price
data['Price(in INR)']= data['Price'].apply(lambda x: pd.Series(clean_price(x)))

# %%
# drop cleaned columns
data.drop(['Memory','Display','Storage','Size','Battery','Camera','Weight','Price'],1,inplace=True)

# %%
# Align the columns based on the information
data=data[['Brand_name','Product_name','Processor','Graphics adapter','PL1(in W)','PL2(in W)','Memory(in GB)','Storage(in GB)',
           'Display(in inches)','Aspect_ratio','Battery(in Wh)','Weight(in kg)','Camera(in MP)','Height(in inches)',
           'Width(in inches)','Depth(in inches)','Price(in INR)','URL_link']]

# %%
data.head(3)
# Out:
#   Brand_name                                       Product_name  \
# 0     Lenovo     Lenovo Yoga 6 13 82ND0009US (Yoga 6 13 Series)
# 1       Asus  Asus ZenBook Flip 13 UX363EA-HP069T (ZenBook F...
# 2     Medion            Medion Erazer Beast X20 (Erazer Series)
#
#                                 Processor  \
# 0       AMD Ryzen 5 5500U 6 x 2.1 - 4 GHz
# 1  Intel Core i7-1165G7 4 x 2.8 - 4.7 GHz
# 2    Intel Core i7-10870H 8 x 2.2 - 5 GHz
#
#                                Graphics adapter PL1(in W) PL2(in W)  \
# 0                 AMD Radeon RX Vega 7 - 512 MB        18        21
# 1               Intel Iris Xe Graphics G7 96EUs        15        51
# 2  NVIDIA GeForce RTX 3070 Laptop GPU - 8192 MB        60        60
#
#    Memory(in GB) Storage(in GB) Display(in inches) Aspect_ratio  \
# 0              8            256              13.30         16:9
# 1             16           1024              13.30         16:9
# 2             32           2048              17.30         16:9
#
#   Battery(in Wh) Weight(in kg) Camera(in MP) Height(in inches)  \
# 0             60         1.331           0.9              0.72
# 1             67         1.188           0.9              0.51
# 2             91         2.246           0.9              0.91
#
#   Width(in inches) Depth(in inches) Price(in INR)  \
# 0            12.13             8.13         60000
# 1            12.01             8.31        156513
# 2            15.55            10.31        200013
#
#                                             URL_link
# 0  https://www.notebookcheck.net/Lenovo-Yoga-6-13...
# 1  https://www.notebookcheck.net/Asus-ZenBook-Fli...
# 2  https://www.notebookcheck.net/Medion-Erazer-Be...

# %%
# Sorting dataframe with some features
data.sort_values(['Weight(in kg)', 'Price(in INR)','Storage(in GB)', 'Memory(in GB)','Battery(in Wh)', 'PL1(in W)'], 
                  ascending=[True, True, False, False, False, False],inplace=True)

# %%
# Top 10 efficient laptops
data.head(10)
# Out:
#    Brand_name                                       Product_name  \
# 27       Dell  Dell Latitude 13 7320 Detachable, i7-1180G7 (L...
# 40         LG               LG Gram 14Z90P-G.AA79G (Gram Series)
# 46     Huawei  Huawei MateBook X Silver Frost (2020) (MateBoo...
# 24   Schenker                                 Schenker Vision 14
# 73     Lenovo                     Lenovo ThinkPad X12 20UVS03G00
# 55     Lenovo  Lenovo ThinkPad X1 Carbon G9-20XWCTO1WW (Think...
# 58       Asus   Asus ZenBook 13 UM325S (ZenBook 13 UM325 Series)
# 31         HP    HP Elite Dragonfly Max (Elite Dragonfly Series)
# 50     Lenovo  Lenovo ThinkPad X1 Carbon G9-20XXS00100 (Think...
# 1        Asus  Asus ZenBook Flip 13 UX363EA-HP069T (ZenBook F...
#
#                                  Processor  \
# 27  Intel Core i7-1180G7 4 x 2.2 - 4.6 GHz
# 40  Intel Core i7-1165G7 4 x 2.8 - 4.7 GHz
# 46  Intel Core i5-10210U 4 x 1.6 - 4.2 GHz
# 24  Intel Core i7-1165G7 4 x 2.8 - 4.7 GHz
# 73  Intel Core i7-1160G7 4 x 2.1 - 4.4 GHz
# 55  Intel Core i7-1165G7 4 x 2.8 - 4.7 GHz
# 58     AMD Ryzen 7 5800U 8 x 1.9 - 4.4 GHz
# 31    Intel Core i7-1185G7 4 x 3 - 4.8 GHz
# 50  Intel Core i7-1165G7 4 x 2.8 - 4.7 GHz
# 1   Intel Core i7-1165G7 4 x 2.8 - 4.7 GHz
#
#                              Graphics adapter PL1(in W) PL2(in W)  \
# 27            Intel Iris Xe Graphics G7 96EUs        23        40
# 40  Intel Iris Xe Graphics G7 96EUs - 1024 MB        18        52
# 46           Intel UHD Graphics 620 - 1024 MB         7        30
# 24            Intel Iris Xe Graphics G7 96EUs        30        60
# 73            Intel Iris Xe Graphics G7 96EUs        12        40
# 55            Intel Iris Xe Graphics G7 96EUs        28        36
# 58          AMD Radeon RX Vega 8 (Ryzen 5000)        25        30
# 31            Intel Iris Xe Graphics G7 96EUs        18        35
# 50            Intel Iris Xe Graphics G7 96EUs        28        36
# 1             Intel Iris Xe Graphics G7 96EUs        15        51
#
#     Memory(in GB) Storage(in GB) Display(in inches) Aspect_ratio  \
# 27             16            256              13.00          3:2
# 40             16           1024              14.00        16:10
# 46             16            512              13.00          3:2
# 24             16           1024              14.00        16:10
# 73             16            512              12.30          3:2
# 55             32           1024              14.00        16:10
# 58             16           1024              13.30         16:9
# 31             16            512              13.30         16:9
# 50             32           1024              14.00        16:10
# 1              16           1024              13.30         16:9
#
#    Battery(in Wh) Weight(in kg) Camera(in MP) Height(in inches)  \
# 27             40         0.782             8              0.33
# 40             72         0.967           0.9              0.66
# 46             42         1.009           0.9              0.54
# 24             53         1.028           0.9              0.61
# 73             42         1.107            NA              0.57
# 55             57         1.156            NA              0.59
# 58             67         1.158           0.9              0.55
# 31             56         1.164             5              0.63
# 50             57         1.175           0.9              0.59
# 1              67         1.188           0.9              0.51
#
#    Width(in inches) Depth(in inches) Price(in INR)  \
# 27            11.35             8.19        157500
# 40            12.34             8.47        139113
# 46            11.18             8.11        130413
# 24            12.16             8.46        143550
# 73            11.15             8.01        141810
# 55             12.4             8.72        219240
# 58            11.97             7.99            NA
# 31            11.98             7.78        183750
# 50            12.38             8.72        146073
# 1             12.01             8.31        156513
#
#                                              URL_link
# 27  https://www.notebookcheck.net/Dell-Latitude-13...
# 40  https://www.notebookcheck.net/LG-Gram-14Z90P-i...
# 46  https://www.notebookcheck.net/Huawei-MateBook-...
# 24  https://www.notebookcheck.net/Schenker-Vision-...
# 73  https://www.notebookcheck.net/Lenovo-ThinkPad-...
# 55  https://www.notebookcheck.net/Lenovo-ThinkPad-...
# 58  https://www.notebookcheck.net/Asus-ZenBook-13-...
# 31  https://www.notebookcheck.net/HP-EliteBook-Dra...
# 50  https://www.notebookcheck.net/Lenovo-ThinkPad-...
# 1   https://www.notebookcheck.net/Asus-ZenBook-Fli...
